# %% [markdown]
# <a href="https://colab.research.google.com/github/sakibrj18/SP-Shop/blob/main/IndexTTS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 🏷️ **Credits: [index-tts](https://github.com/index-tts/index-tts)**
#
#
#
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install IndexTTS-2    [🕒 Wait for 2 minutes]
# %cd /content
# !rm -rf /content/index-tts
# !git lfs install
# !git clone https://github.com/index-tts/index-tts.git
# !git clone https://github.com/NeuralFalconYT/index-tts.git
# %cd index-tts
# !git lfs pull
# !wget https://raw.githubusercontent.com/NeuralFalconYT/Useful-Function/refs/heads/main/hf_downloader.py
# !pip install uv --quiet
# !uv sync --all-extras
from IPython.display import clear_output
clear_output()

# %%
#@title Download IndexTTS-2 Model [🕒 Wait for 40 seconds]
# %cd /content/index-tts
from hf_downloader import download_model
from IPython.display import clear_output
clear_output()
def add_share(file_path="/content/index-tts/webui.py"):
    with open(file_path, "r") as f:
        lines = f.readlines()

    for i, line in enumerate(lines):
        if "demo.launch" in line:
            lines[i] = "    demo.launch(share=True, debug=True)\n"

    with open(file_path, "w") as f:
        f.writelines(lines)

    print(f"✅ Updated {file_path} with share=True, debug=True")



model_path = download_model(
    "IndexTeam/IndexTTS-2",
    download_folder="./checkpoints",
    redownload=False
)
clear_output()
print("✅ Model saved at:", model_path)
add_share()
# Out:
# ✅ Model saved at: /content/index-tts/checkpoints/IndexTTS-2
# ✅ Updated /content/index-tts/webui.py with share=True, debug=True

# %%
#@title Run IndexTTS-2  [🕒 Wait for 3 minutes]
# %cd /content/index-tts
# !uv run webui.py --model_dir "/content/index-tts/checkpoints/IndexTTS-2"
# Out:
# /content/index-tts
# >> GPT weights restored from: /content/index-tts/checkpoints/IndexTTS-2/gpt.pth
# GPT2InferenceModel has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# preprocessor_config.json: 100% 275/275 [00:00<00:00, 1.99MB/s]
# config.json: 1.87kB [00:00, 8.31MB/s]
# model.safetensors: 100% 2.32G/2.32G [00:33<00:00, 69.3MB/s]
# semantic_codec/model.safetensors: 100% 177M/177M [00:02<00:00, 77.9MB/s]
# >> semantic_codec weights restored from: /root/.cache/huggingface/hub/models--amphion--MaskGCT/snapshots/265c6cef07625665d0c28d2faafb1415562379dc/semantic_codec/model.safetensors
# cfm loaded
# length_regulator loaded
# gpt_layer loaded
# >> s2mel weights restored from: /content/index-tts/checkpoints/IndexTTS-2/s2mel.pth
# campplus_cn_common.bin: 100% 28.0M/28.0M [00:00<00:00, 36.9MB/s]
# >> campplus_model weights restored from: /root/.cache/huggingface/hub/models--funasr--campplus/snapshots/fb71fe990cbf6031ae6987a2d76fe64f94377b7e/campplus_cn_common.bin
# config.json: 1.41kB [00:00, 6.36MB/s]
# Loading weights from nvidia/bigvgan_v2_22khz_80band_256x
# bigvgan_generator.pt: 100% 449M/449M [00:18<00:00, 24.4MB/s]
# Removing weight norm...
# >> bigvgan weights restored from: nvidia/bigvgan_v2_22khz_80band_256x
# 2025-12-27 03:22:11,632 WETEXT INFO building fst for zh_normalizer ...
# 2025-12-27 03:22:51,132 WETEXT INFO done
# 2025-12-27 03:22:51,132 WETEXT INFO fst path: /content/index-tts/indextts/utils/tagger_cache/zh_tn_tagger.fst
# 2025-12-27 03:22:51,132 WETEXT INFO           /content/index-tts/indextts/utils/tagger_cache/zh_tn_verbalizer.fst
# 2025-12-27 03:22:51,138 WETEXT INFO found existing fst: /content/index-tts/.venv/lib/python3.10/site-packages/tn/en_tn_tagger.fst
# 2025-12-27 03:22:51,138 WETEXT INFO                     /content/index-tts/.venv/lib/python3.10/site-packages/tn/en_tn_verbalizer.fst
# 2025-12-27 03:22:51,138 WETEXT INFO skip building fst for en_normalizer ...
# >> TextNormalizer loaded
# >> bpe model loaded from: /content/index-tts/checkpoints/IndexTTS-2/bpe.model
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://929070db84bddb27d1.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Emo control mode:0,vec:None
# >> start inference...
# Use the specified emotion vector
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.53.0. You should pass an instance of `Cache` instead, e.g. `past_key_values=DynamicCache.from_legacy_cache(past_key_values)`.
# 100% 25/25 [00:24<00:00,  1.02it/s]
# torch.Size([1, 517632])
# Use the specified emotion vector
# 100% 25/25 [00:19<00:00,  1.28it/s]
# torch.Size([1, 424704])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.13it/s]
# torch.Size([1, 451584])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.00it/s]
# torch.Size([1, 548608])
# Use the specified emotion vector
# 100% 25/25 [00:26<00:00,  1.07s/it]
# torch.Size([1, 570880])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.12it/s]
# torch.Size([1, 479744])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.01it/s]
# torch.Size([1, 548864])
# Use the specified emotion vector
# 100% 25/25 [00:19<00:00,  1.26it/s]
# torch.Size([1, 399616])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.02it/s]
# torch.Size([1, 526080])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.10it/s]
# torch.Size([1, 486400])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.04it/s]
# torch.Size([1, 495616])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.13it/s]
# torch.Size([1, 470528])
# Use the specified emotion vector
# 100% 25/25 [00:21<00:00,  1.14it/s]
# torch.Size([1, 448000])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.04it/s]
# torch.Size([1, 493568])
# Use the specified emotion vector
# 100% 25/25 [00:19<00:00,  1.25it/s]
# torch.Size([1, 405504])
# Use the specified emotion vector
# 100% 25/25 [00:21<00:00,  1.15it/s]
# torch.Size([1, 442368])
# Use the specified emotion vector
# 100% 25/25 [00:21<00:00,  1.18it/s]
# torch.Size([1, 433152])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.02it/s]
# torch.Size([1, 520448])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.12it/s]
# torch.Size([1, 481536])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.13it/s]
# torch.Size([1, 461824])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.01it/s]
# torch.Size([1, 540928])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.02it/s]
# torch.Size([1, 528640])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.13it/s]
# torch.Size([1, 452096])
# Use the specified emotion vector
# 100% 25/25 [00:19<00:00,  1.27it/s]
# torch.Size([1, 387328])
# Use the specified emotion vector
# 100% 25/25 [00:21<00:00,  1.14it/s]
# torch.Size([1, 461312])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.12it/s]
# torch.Size([1, 476672])
# Use the specified emotion vector
# 100% 25/25 [00:19<00:00,  1.28it/s]
# torch.Size([1, 381952])
# Use the specified emotion vector
# 100% 25/25 [00:09<00:00,  2.65it/s]
# torch.Size([1, 83200])
# >> gpt_gen_time: 908.47 seconds
# >> gpt_forward_time: 0.59 seconds
# >> s2mel_time: 631.19 seconds
# >> bigvgan_time: 60.98 seconds
# >> Total inference time: 1637.17 seconds
# >> Generated audio length: 591.29 seconds
# >> RTF: 2.7688
# >> wav file saved to: outputs/spk_1766805824.wav
# Emo control mode:1,vec:None
# >> start inference...
# Use the specified emotion vector
# 100% 25/25 [00:25<00:00,  1.00s/it]
# torch.Size([1, 506368])
# Use the specified emotion vector
# 100% 25/25 [00:20<00:00,  1.25it/s]
# torch.Size([1, 425216])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.13it/s]
# torch.Size([1, 474880])
# Use the specified emotion vector
# 100% 25/25 [00:26<00:00,  1.06s/it]
# torch.Size([1, 562176])
# Use the specified emotion vector
# 100% 25/25 [00:26<00:00,  1.06s/it]
# torch.Size([1, 570624])
# Use the specified emotion vector
# 100% 25/25 [00:21<00:00,  1.15it/s]
# torch.Size([1, 447744])
# Use the specified emotion vector
# 100% 25/25 [00:26<00:00,  1.07s/it]
# torch.Size([1, 578560])
# Use the specified emotion vector
# 100% 25/25 [00:19<00:00,  1.27it/s]
# torch.Size([1, 392704])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.02it/s]
# torch.Size([1, 521216])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.11it/s]
# torch.Size([1, 487424])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.12it/s]
# torch.Size([1, 472832])
# Use the specified emotion vector
# 100% 25/25 [00:21<00:00,  1.14it/s]
# torch.Size([1, 464384])
# Use the specified emotion vector
# 100% 25/25 [00:19<00:00,  1.25it/s]
# torch.Size([1, 409856])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.02it/s]
# torch.Size([1, 510976])
# Use the specified emotion vector
# 100% 25/25 [00:19<00:00,  1.25it/s]
# torch.Size([1, 420864])
# Use the specified emotion vector
# 100% 25/25 [00:19<00:00,  1.25it/s]
# torch.Size([1, 409344])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.02it/s]
# torch.Size([1, 512768])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.03it/s]
# torch.Size([1, 509696])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.12it/s]
# torch.Size([1, 474112])
# Use the specified emotion vector
# 100% 25/25 [00:21<00:00,  1.15it/s]
# torch.Size([1, 449792])
# Use the specified emotion vector
# 100% 25/25 [00:24<00:00,  1.02it/s]
# torch.Size([1, 532992])
# Use the specified emotion vector
# 100% 25/25 [00:23<00:00,  1.05it/s]
# torch.Size([1, 500992])
# Use the specified emotion vector
# 100% 25/25 [00:21<00:00,  1.14it/s]
# torch.Size([1, 466176])
# Use the specified emotion vector
# 100% 25/25 [00:19<00:00,  1.28it/s]
# torch.Size([1, 389632])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.12it/s]
# torch.Size([1, 474112])
# Use the specified emotion vector
# 100% 25/25 [00:22<00:00,  1.10it/s]
# torch.Size([1, 488192])
# Use the specified emotion vector
# 100% 25/25 [00:20<00:00,  1.19it/s]
# torch.Size([1, 425728])
# Use the specified emotion vector
# 100% 25/25 [00:09<00:00,  2.65it/s]
# torch.Size([1, 90112])
# >> gpt_gen_time: 899.31 seconds
# >> gpt_forward_time: 0.59 seconds
# >> s2mel_time: 633.37 seconds
# >> bigvgan_time: 60.39 seconds
# >> Total inference time: 1623.39 seconds
# >> Generated audio length: 593.58 seconds
# >> RTF: 2.7349
# >> wav file saved to: outputs/spk_1766807994.wav
